# %%
#Resume Parsing(Email,Phone no.,Address,Date)
import tika
from tika import parser
import re
class ResumeParsing :
    def parseAnyFile() :
        tika.initVM()
        parsed = parser.from_file('Resume.docx')
        content = parsed["content"]
        print(content+'\n')
        print("After Parsing:")
        emails = re.findall(r'[\w\.-]+@[\w\.-]+', content)
        phnos = re.findall(r'[+0-9 ]{10,15}', content)
        addresses = re.findall(r'Address[\w /,-:]+[.]', content)
        dates = re.findall(r'[0-9]+[,/-]+[0-9]+[,/-]+[0-9]{2,4}', content)
        dollars = re.findall(r'\$[0-9]*[,[0-9]*]*\ ', content)
        
        print("Email id:")
        for email in emails :
            print('\t', email)
        print("Phone No.:")
        for phno in phnos :
            print('\t', phno)
        print("Addresses:")
        for address in addresses :
            print('\t', address)
        print("Dates:")
        for date in dates :
            print('\t', date)
            
    if __name__ == "__main__" :
        parseAnyFile()
# Out:
# ---------------------------------------------------------------------------
# ConnectionRefusedError                    Traceback (most recent call last)
# C:\Users\admin\Anaconda3\lib\site-packages\requests\packages\urllib3\connection.py in _new_conn(self)
#     140
# --> 141         return conn
#     142
#
# C:\Users\admin\Anaconda3\lib\site-packages\requests\packages\urllib3\util\connection.py in create_connection(address, timeout, source_address, socket_options)
#      82             err = _
# ---> 83             if sock is not None:
#      84                 sock.close()
#
# C:\Users\admin\Anaconda3\lib\site-packages\requests\packages\urllib3\util\connection.py in create_connection(address, timeout, source_address, socket_options)
#      72             _set_socket_options(sock, socket_options)
# ---> 73
#      74             if timeout is not socket._GLOBAL_DEFAULT_TIMEOUT:
#
# ConnectionRefusedError: [WinError 10061] No connection could be made because the target machine actively refused it
#
# During handling of the above exception, another exception occurred:
#
# NewConnectionError                        Traceback (most recent call last)
# C:\Users\admin\Anaconda3\lib\site-packages\requests\packages\urllib3\connectionpool.py in urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, **response_kw)
#     599             log.info("Redirecting %s -> %s" % (url, redirect_location))
# --> 600             return self.urlopen(method, redirect_location, body, headers,
#     601                     retries=retries, redirect=redirect,
#
# C:\Users\admin\Anaconda3\lib\site-packages\requests\packages\urllib3\connectionpool.py in _make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     355                 httplib_response = conn.getresponse()
# --> 356         except (SocketTimeout, BaseSSLError, SocketError) as e:
#     357             self._raise_timeout(err=e, url=url, timeout_value=read_timeout)
#
# C:\Users\admin\Anaconda3\lib\http\client.py in request(self, method, url, body, headers, encode_chunked)
#    1238         """Send a complete request to the server."""
# -> 1239         self._send_request(method, url, body, headers, encode_chunked)
#    1240
#
# C:\Users\admin\Anaconda3\lib\http\client.py in _send_request(self, method, url, body, headers, encode_chunked)
#    1284             body = _encode(body, 'body')
# -> 1285         self.endheaders(body, encode_chunked=encode_chunked)
#    1286
#
# C:\Users\admin\Anaconda3\lib\http\client.py in endheaders(self, message_body, encode_chunked)
#    1233             raise CannotSendHeader()
# -> 1234         self._send_output(message_body, encode_chunked=encode_chunked)
#    1235
#
# C:\Users\admin\Anaconda3\lib\http\client.py in _send_output(self, message_body, encode_chunked)
#    1025         del self._buffer[:]
# -> 1026         self.send(msg)
#    1027
#
# C:\Users\admin\Anaconda3\lib\http\client.py in send(self, data)
#     963             if self.auto_open:
# --> 964                 self.connect()
#     965             else:
#
# C:\Users\admin\Anaconda3\lib\site-packages\requests\packages\urllib3\connection.py in connect(self)
#     165         HTTPConnection.__init__(self, host, port, strict=strict,
# --> 166                                 timeout=timeout, **kw)
#     167
#
# C:\Users\admin\Anaconda3\lib\site-packages\requests\packages\urllib3\connection.py in _new_conn(self)
#     149             # TODO: Fix tunnel so it doesn't depend on self.sock state.
# --> 150             self._tunnel()
#     151             # Mark this connection as not reusable
#
# NewConnectionError: <requests.packages.urllib3.connection.HTTPConnection object at 0x000001F430ECCC88>: Failed to establish a new connection: [WinError 10061] No connection could be made because the target machine actively refused it
#
# During handling of the above exception, another exception occurred:
#
# MaxRetryError                             Traceback (most recent call last)
# C:\Users\admin\Anaconda3\lib\site-packages\requests\adapters.py in send(self, request, stream, timeout, verify, cert, proxies)
#     437         return self.build_response(request, resp)
#
# C:\Users\admin\Anaconda3\lib\site-packages\requests\packages\urllib3\connectionpool.py in urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, **response_kw)
#     648                  **conn_kw):
# --> 649
#     650         HTTPConnectionPool.__init__(self, host, port, strict, timeout, maxsize,
#
# C:\Users\admin\Anaconda3\lib\site-packages\requests\packages\urllib3\util\retry.py in increment(self, method, url, response, error, _pool, _stacktrace)
#
# MaxRetryError: HTTPConnectionPool(host='localhost', port=9998): Max retries exceeded with url: /rmeta/text (Caused by NewConnectionError('<requests.packages.urllib3.connection.HTTPConnection object at 0x000001F430ECCC88>: Failed to establish a new connection: [WinError 10061] No connection could be made because the target machine actively refused it',))
#
# During handling of the above exception, another exception occurred:
#
# ConnectionError                           Traceback (most recent call last)
# <ipython-input-7-2286182e55ff> in <module>()
#       3 from tika import parser
#       4 import re
# ----> 5 class ResumeParsing :
#       6     def parseAnyFile() :
#       7         tika.initVM()
#
# <ipython-input-7-2286182e55ff> in ResumeParsing()
#      30
#      31     if __name__ == "__main__" :
# ---> 32         parseAnyFile()
#
# <ipython-input-7-2286182e55ff> in parseAnyFile()
#       6     def parseAnyFile() :
#       7         tika.initVM()
# ----> 8         parsed = parser.from_file('Resume.docx')
#       9         content = parsed["content"]
#      10         print(content+'\n')
#
# C:\Users\admin\Anaconda3\lib\site-packages\tika\parser.py in from_file(filename, serverEndpoint, xmlContent)
#      32     '''
#      33     if not xmlContent:
# ---> 34         jsonOutput = parse1('all', filename, serverEndpoint)
#      35     else:
#      36         jsonOutput = parse1('all', filename, serverEndpoint, services={'meta': '/meta', 'text': '/tika', 'all': '/rmeta/xml'})
#
# C:\Users\admin\Anaconda3\lib\site-packages\tika\tika.py in parse1(option, urlOrPath, serverEndpoint, verbose, tikaServerJar, responseMimeType, services, rawResponse)
#     309     status, response = callServer('put', serverEndpoint, service, open(path, 'rb'),
#     310                                   {'Accept': responseMimeType, 'Content-Disposition': make_content_disposition_header(path)},
# --> 311                                   verbose, tikaServerJar, rawResponse=rawResponse)
#     312
#     313
#
# C:\Users\admin\Anaconda3\lib\site-packages\tika\tika.py in callServer(verb, serverEndpoint, service, data, headers, verbose, tikaServerJar, httpVerbs, classpath, rawResponse)
#     519         encodedData = data.encode('utf-8')
#     520
# --> 521     resp = verbFn(serviceUrl, encodedData, headers=headers, verify=False)
#     522     if verbose:
#     523         print(sys.stderr, "Request headers: ", headers)
#
# C:\Users\admin\Anaconda3\lib\site-packages\requests\api.py in put(url, data, **kwargs)
#     124 def delete(url, **kwargs):
#     125     """Sends a DELETE request. Returns :class:`Response` object.
# --> 126
#     127     :param url: URL for the new :class:`Request` object.
#     128     :param \*\*kwargs: Optional arguments that ``request`` takes.
#
# C:\Users\admin\Anaconda3\lib\site-packages\requests\api.py in request(method, url, **kwargs)
#      56
#      57 def get(url, **kwargs):
# ---> 58     """Sends a GET request. Returns :class:`Response` object.
#      59
#      60     :param url: URL for the new :class:`Request` object.
#
# C:\Users\admin\Anaconda3\lib\site-packages\requests\sessions.py in request(self, method, url, params, data, headers, cookies, files, auth, timeout, allow_redirects, proxies, hooks, stream, verify, cert, json)
#     516     def patch(self, url, data=None, **kwargs):
#     517         """Sends a PATCH request. Returns :class:`Response` object.
# --> 518
#     519         :param url: URL for the new :class:`Request` object.
#     520         :param data: (optional) Dictionary, bytes, or file-like object to send in the body of the :class:`Request`.
#
# C:\Users\admin\Anaconda3\lib\site-packages\requests\sessions.py in send(self, request, **kwargs)
#     637
#     638     def get_adapter(self, url):
# --> 639         """Returns the appropriate connnection adapter for the given URL."""
#     640         for (prefix, adapter) in self.adapters.items():
#     641
#
# C:\Users\admin\Anaconda3\lib\site-packages\requests\adapters.py in send(self, request, stream, timeout, verify, cert, proxies)
#
# ConnectionError: HTTPConnectionPool(host='localhost', port=9998): Max retries exceeded with url: /rmeta/text (Caused by NewConnectionError('<requests.packages.urllib3.connection.HTTPConnection object at 0x000001F430ECCC88>: Failed to establish a new connection: [WinError 10061] No connection could be made because the target machine actively refused it',))
